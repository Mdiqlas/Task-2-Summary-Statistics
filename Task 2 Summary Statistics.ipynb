# %% [markdown]
# # **TASK-2**
#
# ## **Calculating summary statistics for a given titanic dataset**
#
# ### **Importing the Python libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### **Importing the dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/Task-2 Summay Statistics/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # **Data Cleaning**
#
# ## **Before calculating the summary statistics of the dataset we have to clean the data to get the accurate summary of the data.**
#
# ### **Counting the No of missing values in each column**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### **Visualizing the missing data using Heat Map**

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %% [markdown]
# ### **Calculating the percentage of missing values in Dataframe**

# %%
missing_values=(df.isnull().sum()/len(df))*100
print(missing_values)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# ### **Dropping the row when whole row is null**

# %%
df.dropna(how="all")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## **Dropping the null values in the column 'Embarked'**

# %%
df.dropna(subset=['Embarked'], inplace=True)

# %% [markdown]
# ### **Counting the No of unique values in the Cabin column of the Dataframe**

# %%
df["Cabin"].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# E101           3
# C22 C26        3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 146, dtype: int64

# %% [markdown]
# ### **Calculating the mode of Cabin column**

# %%
df["Cabin"].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %% [markdown]
# ### **Replacing the missing values with mode values in Cabin column**

# %%
df['Cabin'].fillna(df['Cabin'].mode()[2],inplace=True)

# %% [markdown]
# #**Removing the missing data from age column**
#
# Calculates the first quartile (Q1) and the third quartile (Q3) of the 'Age' column in a DataFrame.Calculates the interquartile range (IQR) for a dataset which representing the range between the first quartile (Q1) and the third quartile (Q3).

# %%
Q1=df.Age.quantile(0.25)
Q3=df.Age.quantile(0.75)

Q1,Q3

IQR=Q3-Q1
IQR

lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (-7.0, 65.0)

# %% [markdown]
# ### **Identifing the data without oulliers**

# %%
no_outlier=df[(df.Age>=lower_limit)&(df.Age<=upper_limit)]
no_outlier
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## **Calculating the mean of Age column**

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %% [markdown]
# ##**Checking for null values**

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ##**Visualization of heatmap without missing values**

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %% [markdown]
# #**Calculating the summary statistics of data science**
# ###**Method 1: Statistical details of Dataframe**

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586   29.642093    0.524184
# std     256.998173    0.486260    0.834700   12.968346    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.642093    0.000000
# 75%     668.000000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.382452   32.096681
# std      0.806761   49.697504
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #**Method 2: Calculating the Mean, Median, Mode and Standard deviation seperately.**
#
# ###**Calculating the mean of the dataset which the column has only numeric values.**

# %%
df.mean(numeric_only=True)
# Out:
# PassengerId    446.000000
# Survived         0.382452
# Pclass           2.311586
# Age             29.642093
# SibSp            0.524184
# Parch            0.382452
# Fare            32.096681
# dtype: float64

# %% [markdown]
# ###**Calculating the median of the dataset which the column has only numeric values.**

# %%
df.median(numeric_only=True)
# Out:
# PassengerId    446.000000
# Survived         0.000000
# Pclass           3.000000
# Age             29.642093
# SibSp            0.000000
# Parch            0.000000
# Fare            14.454200
# dtype: float64

# %% [markdown]
# ###**Calculating the mode of dataset.**

# %%
df.mode()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 0              1       0.0     3.0                    Abbing, Mr. Anthony
# 1              2       NaN     NaN            Abbott, Mr. Rossmore Edward
# 2              3       NaN     NaN       Abbott, Mrs. Stanton (Rosa Hunt)
# 3              4       NaN     NaN                    Abelson, Mr. Samuel
# 4              5       NaN     NaN  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 884          887       NaN     NaN                de Mulder, Mr. Theodore
# 885          888       NaN     NaN              de Pelsmaeker, Mr. Alfons
# 886          889       NaN     NaN              del Carlo, Mr. Sebastiano
# 887          890       NaN     NaN        van Billiard, Mr. Austin Blyler
# 888          891       NaN     NaN            van Melkebeke, Mr. Philemon
#
#       Sex        Age  SibSp  Parch    Ticket  Fare Cabin Embarked
# ...

# %% [markdown]
# ###**Calculating the Standard deviation of the dataset which the column has only numeric values.**

# %%
df.std(numeric_only=True)
# Out:
# PassengerId    256.998173
# Survived         0.486260
# Pclass           0.834700
# Age             12.968346
# SibSp            1.103705
# Parch            0.806761
# Fare            49.697504
# dtype: float64

# %% [markdown]
# # **Importing the second file.**

# %%
df1=pd.read_csv("/content/drive/MyDrive/Task-2 Summay Statistics/gender_submission.csv")

# %% [markdown]
# ## **Checking the null values**

# %%
df1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %% [markdown]
# **The file does not contain null values**

# %% [markdown]
# ## **Printing the dataset**

# %%
df1
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %% [markdown]
# ###**Method 1: Statistical details of Dataframe**

# %%
df1.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %% [markdown]
# #**Method 2: Calculating the Mean, Median, Mode and Standard deviation seperately.**
#
# ###**Calculating the mean of the dataset which the column has only numeric values.**

# %%
df1.mean(numeric_only=True)
# Out:
# PassengerId    1100.500000
# Survived          0.363636
# dtype: float64

# %% [markdown]
# ###**Calculating the median of the dataset which the column has only numeric values.**

# %%
df1.median(numeric_only=True)
# Out:
# PassengerId    1100.5
# Survived          0.0
# dtype: float64

# %% [markdown]
# ###**Calculating the mode of dataset.**

# %%
df1.mode()
# Out:
#      PassengerId  Survived
# 0            892       0.0
# 1            893       NaN
# 2            894       NaN
# 3            895       NaN
# 4            896       NaN
# ..           ...       ...
# 413         1305       NaN
# 414         1306       NaN
# 415         1307       NaN
# 416         1308       NaN
# 417         1309       NaN
#
# [418 rows x 2 columns]

# %% [markdown]
# ###**Calculating the Standard deviation of the dataset which the column has only numeric values.**

# %%
df1.std(numeric_only=True)
# Out:
# PassengerId    120.810458
# Survived         0.481622
# dtype: float64

# %% [markdown]
# # **Importing the third file.**

# %%
df2=pd.read_csv("/content/drive/MyDrive/Task-2 Summay Statistics/test.csv")
df2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# ##**Calculating the null values.**

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# #**Cleaning the missing values**
# ##**Calculating the mean of Age column**

# %%
df2["Age"].mean()
# Out:
# 30.272590361445783

# %% [markdown]
# ## **Replacing the null values of Age by mean**

# %%
df2['Age'].fillna(df2['Age'].mean(),inplace=True)

# %% [markdown]
# ## **Replacing the null values of Age by mean**

# %%
df2.dropna(subset=['Fare'], inplace=True)

# %% [markdown]
# ##**Calculating the null values.**

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          326
# Embarked         0
# dtype: int64

# %% [markdown]
# ### **Calculating the mode of Cabin column**

# %%
df2["Cabin"].mode()
# Out:
# 0    B57 B59 B63 B66
# Name: Cabin, dtype: object

# %% [markdown]
# ## **Replacing the missing values with mode values in Cabin column.**

# %%
df2['Cabin'].fillna(df2['Cabin'].mode()[0],inplace=True)

# %% [markdown]
# ## **Checking the updated null values.**

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# #**Method 1: Statistical details of Dataframe**

# %%
df2.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   417.000000  417.000000  417.000000  417.000000  417.000000  417.000000
# mean   1100.635492    2.263789   30.200103    0.448441    0.393285   35.627188
# std     120.923774    0.842077   12.562386    0.897568    0.982419   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.000000    1.000000   23.000000    0.000000    0.000000    7.895800
# 50%    1101.000000    3.000000   30.272590    0.000000    0.000000   14.454200
# 75%    1205.000000    3.000000   35.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# #**Method 2: Calculating the Mean, Median, Mode and Standard deviation seperately.**
#
# ###**Calculating the mean of the dataset which the column has only numeric values.**

# %%
df2.mean(numeric_only=True)
# Out:
# PassengerId    1100.635492
# Pclass            2.263789
# Age              30.200103
# SibSp             0.448441
# Parch             0.393285
# Fare             35.627188
# dtype: float64

# %% [markdown]
# ###**Calculating the median of the dataset which the column has only numeric values.**

# %%
df2.median(numeric_only=True)
# Out:
# PassengerId    1101.00000
# Pclass            3.00000
# Age              30.27259
# SibSp             0.00000
# Parch             0.00000
# Fare             14.45420
# dtype: float64

# %% [markdown]
# ###**Calculating the mode of dataset.**

# %%
df2.mode()
# Out:
#      PassengerId  Pclass                                           Name   Sex  \
# 0            892     3.0                  Abbott, Master. Eugene Joseph  male
# 1            893     NaN                    Abelseth, Miss. Karen Marie   NaN
# 2            894     NaN                  Abelseth, Mr. Olaus Jorgensen   NaN
# 3            895     NaN       Abrahamsson, Mr. Abraham August Johannes   NaN
# 4            896     NaN      Abrahim, Mrs. Joseph (Sophie Halaut Easu)   NaN
# ..           ...     ...                                            ...   ...
# 412         1305     NaN                     de Brito, Mr. Jose Joaquim   NaN
# 413         1306     NaN           de Messemaeker, Mr. Guillaume Joseph   NaN
# 414         1307     NaN  del Carlo, Mrs. Sebastiano (Argenia Genovesi)   NaN
# 415         1308     NaN            van Billiard, Master. James William   NaN
# 416         1309     NaN              van Billiard, Master. Walter John   NaN
#
# ...

# %% [markdown]
# ###**Calculating the Standard deviation of the dataset which the column has only numeric values.**

# %%
df2.std(numeric_only=True)
# Out:
# PassengerId    120.923774
# Pclass           0.842077
# Age             12.562386
# SibSp            0.897568
# Parch            0.982419
# Fare            55.907576
# dtype: float64
